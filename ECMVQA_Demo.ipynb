# %% [markdown]
# <a href="https://colab.research.google.com/github/SSK0414/ECMVQA/blob/main/ECMVQA_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Demo

# %%
# %cd /content
# Out:
# /content

# %%
# Clone the repo
# !git clone https://github.com/farisalasmary/sbvqa2.0.git
# Out:
# fatal: destination path 'sbvqa2.0' already exists and is not an empty directory.

# %%
# install dependencies (part 1)
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install Cython
# !pip install -U --no-cache nemo_toolkit['all']
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# install dependencies (part 2)
# !pip uninstall -y pydub
# !pip install git+https://github.com/farisalasmary/pydub.git@master
# !pip install -U transformers==4.16.0 timm==0.4.12 fairscale==0.4.4
# !pip install flask_cors pyngrok
# !pip install -U git+https://github.com/jacobgil/pytorch-grad-cam.git@1ff3f58
# Out:
# Found existing installation: pydub 0.25.1
# Uninstalling pydub-0.25.1:
#   Successfully uninstalled pydub-0.25.1
# ...
#   Cloning https://github.com/farisalasmary/pydub.git (to revision master) to /tmp/pip-req-build-8zmsh1_1
#   Running command git clone --filter=blob:none --quiet https://github.com/farisalasmary/pydub.git /tmp/pip-req-build-8zmsh1_1
#   Resolved https://github.com/farisalasmary/pydub.git to commit 61342a72dc290628f4bb187735fc2b113fc91c5f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydub: filename=pydub-0.25.1-py2.py3-none-any.whl size=32380 sha256=05a67072548d534c42f567e6b7247c8ed4ef3373e151da7f612ec96dbb686a0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rox7ixbo/wheels/7d/98/37/a7cc1a832b38d3ef185486db50d72027f3744fe3df5b2fc340
# Successfully built pydub
# ...
#   Using cached transformers-4.16.0-py3-none-any.whl.metadata (61 kB)
# ...
# Using cached transformers-4.16.0-py3-none-any.whl (3.5 MB)
# ...
#   Attempting uninstall: transformers
# ...

# %%
# %cd /content/sbvqa2.0/
# Out:
# /content/sbvqa2.0

# %%
# Download models
# !gdown -c --fuzzy -O models/ https://drive.google.com/file/d/13mX_X3aS4MI_JX1UtYU0mIxXjaJFAzdZ/view?usp=sharing
# !gdown -c --fuzzy -O models/ https://drive.google.com/file/d/13j7T8dpKcjD499e6DGm4RL4UYjl1Kvvu/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=13mX_X3aS4MI_JX1UtYU0mIxXjaJFAzdZ
# From (redirected): https://drive.google.com/uc?id=13mX_X3aS4MI_JX1UtYU0mIxXjaJFAzdZ&confirm=t&uuid=3dfa1e92-d74d-4d84-95f3-c461e966afe5
# To: /content/sbvqa2.0/models/stt_en_conformer_ctc_large_24500_hours_bpe.nemo
# 100% 487M/487M [00:07<00:00, 67.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=13j7T8dpKcjD499e6DGm4RL4UYjl1Kvvu
# From (redirected): https://drive.google.com/uc?id=13j7T8dpKcjD499e6DGm4RL4UYjl1Kvvu&confirm=t&uuid=233dafb3-4a70-42ae-8750-a4847e8997d4
# To: /content/sbvqa2.0/models/best_sbvqa_2.0_model.pt
# 100% 1.76G/1.76G [00:19<00:00, 89.6MB/s]

# %%
# !mkdir -p uploads/

# %%
# !pip install numpy==1.26.4

# %%
# !python sbvqa2.0/website_gradio_gpu.py
# Out:
# [NeMo W 2025-10-09 15:37:52 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/megatron/core/distributed/fsdp/src/megatron_fsdp/utils.py:109: UserWarning: Transformer Engine and Apex are not installed. Falling back to local implementations of multi_tensor_applier and multi_tensor_scale
#       warnings.warn(
#
# [NeMo W 2025-10-09 15:37:52 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/megatron/core/optimizer/__init__.py:18: UserWarning: Transformer Engine and Apex are not installed. Falling back to Torch optimizers.
#       warnings.warn(
#
# [NeMo W 2025-10-09 15:37:52 nemo_logging:405] /usr/local/lib/python3.12/dist-packages/megatron/core/optimizer/optimizer.py:27: UserWarning: Transformer Engine and Apex are not installed. Falling back to local implementations of multi_tensor_applier and multi_tensor_scale
#       warnings.warn(
#
# ...

# %%
# Replace "YOUR_AUTH_TOKEN" with your actual ngrok authtoken
# !ngrok config add-authtoken 339cLOjaWOLrzLHaceK8wd6A5bY_5jFEymmQg5rkE2rbs7vNy
